# %% [markdown]
# <a href="https://colab.research.google.com/github/rafaelrpq/classificadores/blob/main/classificadores_metricas_ponderadas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import numpy as np
import torch
import torch.utils.data
import torchvision.transforms as transforms
import torchvision.datasets as datasets
from torch.utils.data import DataLoader, Subset

from sklearn.model_selection import train_test_split, KFold
from sklearn.svm import SVC
from sklearn.neural_network import MLPClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import (
    accuracy_score, precision_score, recall_score, f1_score,
    balanced_accuracy_score, confusion_matrix
)

from transformers import AutoModel
import warnings
import kagglehub
# For progress bars
from tqdm import tqdm
# To help with aggregation
from collections import defaultdict

# Import plotting libraries
import matplotlib.pyplot as plt
import seaborn as sns
import json # Added for stable parameter key

# Suppress specific warnings
warnings.filterwarnings("ignore", category=FutureWarning)
# For sklearn metrics zero_division
warnings.filterwarnings("ignore", category=UserWarning)

# Configurar dispositivo (GPU se disponível)
device = torch.device ("cuda" if torch.cuda.is_available () else "cpu")
print (f"Usando o dispositivo: {device}")

# Hiperparametros
hyperparameters = {
    "SVC": [{"C": c} for c in [0.1, 1, 10, 100, 1000]],
    "MLPClassifier": [{"hidden_layer_sizes": hls, "max_iter" : 200, "random_state": 42} for hls in [(50,), (100,), (50, 50), (100, 100), (200, 200)]], # Added random_state
    "RandomForestClassifier": [{"n_estimators": n, "random_state" : 42} for n in [10, 50, 100, 200, 500]],
    "KNeighborsClassifier": [{"n_neighbors": k} for k in [1, 3, 5, 7, 9]]
}

# Transformação das imagens
transform = transforms.Compose ([
    transforms.Resize ((224, 224)),
    transforms.ToTensor (),
    transforms.Normalize (mean=[0.5, 0.5, 0.5], std=[0.5, 0.5, 0.5])
])

# --- Dataset Loading ---
# Carregar o dataset usando kagglehub
print("Downloading dataset...")
path = kagglehub.dataset_download("mudasirazhar/cyanotoxins-identification-dataset")
print("Path to dataset files:", path)


# Diretório das imagens
train_data_dir = os.path.join (path,"Dataset/Train")
# Assumindo que um diretório 'Test' existe baseda na estrutra comum dos datasets
test_data_dir = os.path.join (path,"Dataset/Test")

# Carregar os conjuntos de dados de treino e teste (se houver diretórios separados)
# Se não houver Test directory, use train_test_split on the single directory
if not os.path.exists(test_data_dir):
    print("Test directory not found. Splitting train directory.")
    full_dataset = datasets.ImageFolder(root=train_data_dir, transform=transform)
    test_ratio = 0.2

    train_indices, test_indices = train_test_split(list(range(len(full_dataset))),
        test_size=test_ratio,
        random_state=42,
        stratify=full_dataset.targets
    )
    train_dataset = Subset(full_dataset, train_indices)
    test_dataset = Subset(full_dataset, test_indices)

    class_names = full_dataset.classes
    num_classes = len(class_names)

else:
    print("Found Train and Test directories.")
    train_dataset = datasets.ImageFolder(root=train_data_dir, transform=transform)
    test_dataset = datasets.ImageFolder(root=test_data_dir, transform=transform)
    class_names = train_dataset.classes # Assume train_dataset has all classes
    num_classes = len(class_names)


print(f"Train dataset size: {len(train_dataset)}")
print(f"Test dataset size: {len(test_dataset)}")
print(f"Classes: {class_names}")


# Dataloaders para a extração inicial de features do conjunto COMPLETO de treino e teste
# Shuffle False for feature extraction to maintain order potentially, though not strictly necessary
# Use a larger batch size for extraction if memory allows
full_train_loader = DataLoader(train_dataset, batch_size=64, shuffle=False)
test_loader = DataLoader(test_dataset, batch_size=64, shuffle=False)


# KFold setup (apenas para o conjunto de TREINO inicial)
k_folds = 5
# Note: kf.split will return indices relative to the train_dataset subset if it's a Subset
# If it's the original ImageFolder, it will return indices relative to that.
# Our feature extraction step flattened this, so we need to be careful.
# Since we extract features *before* KFold, KFold should split indices of the *extracted features*.
# The number of samples for KFold should be len(X_train_full).
kf = KFold (n_splits=k_folds, shuffle=True, random_state=42)


# --- Feature Extraction Class ---
class FeatureExtractor :
    def __init__ (self, vit_model_name) :
        try:
             self.model = AutoModel.from_pretrained(vit_model_name).to(device)
             print(f"Loaded {vit_model_name} as AutoModel.")
        except Exception as e:
             print(f"Error loading {vit_model_name} with AutoModel: {e}")
             print("Ensure the model checkpoint is compatible or try a different loading strategy.")
             raise e

        self.model.eval ()
        print(f"Feature extractor model loaded and set to evaluation mode.")

    def extract_features (self, dataloader):
        features = []
        labels = []
        print(f"Extracting features for {len(dataloader.dataset)} samples...")
        with torch.no_grad ():
            for inputs, targets in tqdm(dataloader, desc="Extracting Features"):
                inputs = inputs.to (device)
                outputs = self.model (inputs)

                if hasattr(outputs, 'last_hidden_state') and outputs.last_hidden_state is not None:
                    # Use [:, 0, :] for the CLS token from ViT-like models
                    cls_tokens = outputs.last_hidden_state[:, 0, :]
                elif hasattr(outputs, 'pooler_output') and outputs.pooler_output is not None:
                     # Use pooler_output for models that provide it (e.g., BERT-like)
                    cls_tokens = outputs.pooler_output
                else:
                    # Fallback for unexpected output structures
                    try:
                         # Assuming first element is the main output, and it might have a CLS token
                         cls_tokens = outputs[0][:, 0, :]
                    except Exception as e:
                         print(f"Error accessing fallback output: {e}")
                         print("Model output structure is unexpected. Check model documentation or model type.")
                         raise e


                # Move para CPU e converte para numpy
                features.append (cls_tokens.cpu ().numpy ())
                labels.append (targets.numpy ())

        return np.vstack (features), np.hstack (labels)


# --- Evaluation Function ---
def evaluate_metrics(y_true, y_pred, class_names=None, num_classes=None):
    """Calculates various classification metrics (including macro and weighted) and CM components."""
    acc = accuracy_score(y_true, y_pred)

    unique_classes_true = np.unique(y_true)
    unique_classes_pred = np.unique(y_pred)
    combined_unique_classes = np.unique(np.concatenate((unique_classes_true, unique_classes_pred)))

    # Initialize metrics to NaN/None
    precision_macro, recall_macro, f1_macro = np.nan, np.nan, np.nan
    precision_weighted, recall_weighted, f1_weighted = np.nan, np.nan, np.nan
    balanced = balanced_accuracy_score(y_true, y_pred) # This works even with 1 class

    # Calculate average metrics only if there are at least two classes involved
    # Macro/Weighted metrics are undefined or misleading with only one class present
    if len(combined_unique_classes) >= 2:
        try:
            # Macro Average
            precision_macro = precision_score(y_true, y_pred, average="macro", zero_division=0)
            recall_macro = recall_score(y_true, y_pred, average="macro", zero_division=0)
            f1_macro = f1_score(y_true, y_pred, average="macro", zero_division=0) # Added zero_division

            # Weighted Average
            precision_weighted = precision_score(y_true, y_pred, average="weighted", zero_division=0)
            recall_weighted = recall_score(y_true, y_pred, average="weighted", zero_division=0)
            f1_weighted = f1_score(y_true, y_pred, average="weighted", zero_division=0) # Added zero_division

        except ValueError as e:
             # If sklearn raises a ValueError (e.g., due to no predicted samples in a class for macro)
             # the metrics will remain NaN from initialization
             print(f"Warning: Could not calculate average metrics due to ValueError: {e}")
             pass


    # Calculate Confusion Matrix
    # Ensure all possible class labels are included in CM, even if not present in this fold/batch
    all_possible_labels = np.arange(num_classes) if num_classes is not None else np.unique(np.concatenate((y_true, y_pred)))
    all_possible_labels = np.sort(all_possible_labels) # Ensure sorted order for consistent CM rows/cols
    # Handle cases where a fold might not have all classes present in y_true/y_pred
    # sklearn's confusion_matrix handles this if labels are provided
    cm = confusion_matrix(y_true, y_pred, labels=all_possible_labels)

    n_classes_cm = cm.shape[0]
    cm_metrics_per_class = {}

    # Use class names if available and match CM size, otherwise use generic labels
    current_class_names = class_names if class_names is not None and len(class_names) == n_classes_cm else [f'class_{i}' for i in range(n_classes_cm)]

    # Calculate per-class TP/TN/FP/FN
    total_samples = np.sum(cm)
    for i in range(n_classes_cm):
        class_label = current_class_names[i]

        TP_i = cm[i, i]
        FN_i = np.sum(cm[i, :]) - TP_i # Sum of row i minus TP_i
        FP_i = np.sum(cm[:, i]) - TP_i # Sum of column i minus TP_i
        TN_i = total_samples - TP_i - FN_i - FP_i

        cm_metrics_per_class[class_label] = {'TP': int(TP_i), 'FN': int(FN_i), 'FP': int(FP_i), 'TN': int(TN_i)} # Ensure int

    return {
        "accuracy": float(acc),
        "precision_macro": float(precision_macro) if precision_macro is not np.nan else None,
        "recall_macro": float(recall_macro) if recall_macro is not np.nan else None,
        "f1_macro": float(f1_macro) if f1_macro is not np.nan else None,
        "precision_weighted": float(precision_weighted) if precision_weighted is not np.nan else None, # Added
        "recall_weighted": float(recall_weighted) if recall_weighted is not np.nan else None,       # Added
        "f1_weighted": float(f1_weighted) if f1_weighted is not np.nan else None,             # Added
        "balanced_accuracy": float(balanced),
        "confusion_matrix": cm.tolist(),
        "cm_metrics_per_class": cm_metrics_per_class
    }


# --- Main Execution ---

# Instanciando Extratores de Caracteristicas baseados em ViT Models
vit_extractors = {
    "DINO": FeatureExtractor("facebook/dino-vitb8"),
    "ViT-Base": FeatureExtractor("google/vit-base-patch16-224"),
    "ViT-Large": FeatureExtractor("google/vit-large-patch16-224"),
}

# Instanciando Classificadores (using sklearn class objects directly)
classifiers_map = {
    'SVM': SVC,
    'MLP': MLPClassifier,
    'RandomForest': RandomForestClassifier,
    'KNN': KNeighborsClassifier,
}

# --- 1. Extract features from the FULL train and test datasets ONCE ---
print("\n" + "="*60)
print("--- Initial Feature Extraction (Full Train and Test) ---")
print("="*60)
feature_data = {}

for extractor_name, extractor in vit_extractors.items():
    print(f"\nUsing extractor: {extractor_name}")
    full_train_loader_for_extraction = DataLoader(train_dataset, batch_size=64, shuffle=False)
    test_loader_for_extraction = DataLoader(test_dataset, batch_size=64, shuffle=False)

    X_train_full, y_train_full = extractor.extract_features(full_train_loader_for_extraction)
    X_test_full, y_test_full = extractor.extract_features(test_loader_for_extraction)

    feature_data[extractor_name] = {
        'X_train_full': X_train_full,
        'y_train_full': y_train_full,
        'X_test_full': X_test_full,
        'y_test_full': y_test_full,
    }
    print(f"Extracted features shape (Train): {X_train_full.shape}")
    print(f"Extracted features shape (Test): {X_test_full.shape}")

# --- 2. K-Fold Cross-Validation on Training Data ---
print("\n" + "="*60)
print("--- Starting K-Fold Cross-Validation on Training Data ---")
print("="*60)
kfold_results = []

for extractor_name, data in feature_data.items():
    X_train_full = data['X_train_full']
    y_train_full = data['y_train_full']

    print(f"\n--- K-Fold for Extractor: {extractor_name} ---")

    # Ensure KFold splits the feature array, not the original dataset indices
    kf_split_indices = list(kf.split(X_train_full))


    for fold_idx, (train_indices_fold, val_indices_fold) in enumerate(kf_split_indices):
        print(f"\nProcessing Fold {fold_idx + 1}/{k_folds}")

        X_train_fold = X_train_full[train_indices_fold]
        y_train_fold = y_train_full[train_indices_fold]
        X_val_fold = X_train_full[val_indices_fold]
        y_val_fold = y_train_full[val_indices_fold]

        for clf_name, clf_class in classifiers_map.items():
            clf_hyperparameters = hyperparameters.get(clf_class.__name__, [])

            if not clf_hyperparameters:
                 continue

            for params in tqdm(clf_hyperparameters, desc=f"  Fold {fold_idx+1} {clf_name} Params"):
                try:
                    clf = clf_class(**params)
                    clf.fit(X_train_fold, y_train_fold)
                    y_pred_fold = clf.predict(X_val_fold)
                    # Pass num_classes correctly if splitting dataset
                    metrics = evaluate_metrics(y_val_fold, y_pred_fold, class_names=class_names, num_classes=num_classes)

                    kfold_results.append({
                        'extractor': extractor_name,
                        'fold_idx': fold_idx + 1,
                        'classifier': clf_name,
                        'params': params,
                        'metrics': metrics
                    })

                except Exception as e:
                     print(f"\nError training/predicting {clf_name} with params {params} in fold {fold_idx+1}: {e}")
                     kfold_results.append({
                         'extractor': extractor_name,
                         'fold_idx': fold_idx + 1,
                         'classifier': clf_name,
                         'params': params,
                         'error': str(e)
                     })

print("\n--- K-Fold Cross-Validation Finished ---")
print(f"Total K-Fold results stored (including errors): {len(kfold_results)}")


# --- 3. Analyze K-Fold Results and Select Best Hyperparameters ---
print("\n" + "="*60)
print("--- Analyzing K-Fold Results and Selecting Best Models ---")
print("="*60)

aggregated_kfold_metrics = defaultdict(lambda: defaultdict(list))

# Use json.dumps for a stable dict key representation
params_key_to_dict = {}

for result in kfold_results:
    if 'error' in result:
        continue

    extractor = result['extractor']
    classifier = result['classifier']
    # Create a stable key from params dictionary
    try:
         params_key = json.dumps(result['params'], sort_keys=True)
         params_key_to_dict[params_key] = result['params']
    except:
         # Fallback if params are not JSON serializable (unlikely for this use case)
         params_key = str(result['params'])
         params_key_to_dict[params_key] = result['params']


    for metric_name, metric_value in result['metrics'].items():
        # Only aggregate numerical metrics and None
        if isinstance(metric_value, (int, float)) or (metric_value is None):
             if metric_value is not None: # Don't append None to list for averaging
                aggregated_kfold_metrics[(extractor, classifier, params_key)][metric_name].append(metric_value)


average_kfold_metrics = {}
best_params_per_clf_extractor = {}

selection_metric = 'balanced_accuracy' # Use balanced accuracy for selection

print(f"Selecting best hyperparameters based on average '{selection_metric}' across folds.")

for (extractor, classifier, params_key), metrics_list_dict in aggregated_kfold_metrics.items():
    average_metrics = {
        metric_name: np.nanmean(metric_values) if metric_values else np.nan # Handle empty lists
        for metric_name, metric_values in metrics_list_dict.items()
    }

    average_kfold_metrics[(extractor, classifier, params_key)] = average_metrics

    current_best_info = best_params_per_clf_extractor.get((extractor, classifier))
    current_combination_score = average_metrics.get(selection_metric, np.nan)

    # Select the best parameters based on the selection_metric
    if current_best_info is None or np.isnan(current_best_info['avg_score']) or (not np.isnan(current_combination_score) and current_combination_score > current_best_info['avg_score']):
        original_params = params_key_to_dict.get(params_key, {}) # Get original dict back
        best_params_per_clf_extractor[(extractor, classifier)] = {
            'params': original_params,
            'avg_score': current_combination_score
        }


print("\n--- K-Fold Average Metrics Summary (Best per Classifier/Extractor Combo) ---")

# Sort the best results by the selection metric
sorted_best_kfold = sorted(best_params_per_clf_extractor.items(),
                           key=lambda item: item[1]['avg_score'] if not np.isnan(item[1]['avg_score']) else -float('inf'), # Handle NaN scores
                           reverse=True)

for (extractor, classifier), best_info in sorted_best_kfold:
     best_params = best_info['params']
     avg_score = best_info['avg_score']

     # Use the params_key (string representation) to lookup in average_kfold_metrics
     try:
         best_params_key = json.dumps(best_params, sort_keys=True)
     except:
         best_params_key = str(best_params)

     full_avg_metrics = average_kfold_metrics.get((extractor, classifier, best_params_key), {})

     print(f"\nBest K-Fold Result for Extractor: {extractor}, Classifier: {classifier}")
     print(f"  Selected Params: {best_params}")
     print(f"  Avg {selection_metric}: {avg_score:.4f}" if not np.isnan(avg_score) else f"  Avg {selection_metric}: N/A (all folds failed or metric NaN)")

     # Print all average metrics found for these best parameters
     print(f"  Avg Metrics (Macro): Precision={full_avg_metrics.get('precision_macro', np.nan):.4f}, Recall={full_avg_metrics.get('recall_macro', np.nan):.4f}, F1={full_avg_metrics.get('f1_macro', np.nan):.4f}")
     print(f"  Avg Metrics (Weighted): Precision={full_avg_metrics.get('precision_weighted', np.nan):.4f}, Recall={full_avg_metrics.get('recall_weighted', np.nan):.4f}, F1={full_avg_metrics.get('f1_weighted', np.nan):.4f}")
     print(f"  Avg Accuracy: {full_avg_metrics.get('accuracy', np.nan):.4f}, Avg Balanced Accuracy: {full_avg_metrics.get('balanced_accuracy', np.nan):.4f}")


# --- 4. Final Evaluation on the Test Set (Using Selected Best Hyperparameters) ---
print("\n" + "="*60)
print("--- Starting Final Evaluation on Test Set (Using Selected Best Models) ---")
print("="*60)
final_test_results = []

for extractor_name, data in feature_data.items():
    X_train_full = data['X_train_full']
    y_train_full = data['y_train_full']
    X_test_full = data['X_test_full']
    y_test_full = data['y_test_full']

    print(f"\n--- Testing with Extractor: {extractor_name} ---")

    for clf_name, clf_class in classifiers_map.items():
         best_info = best_params_per_clf_extractor.get((extractor_name, clf_name))

         if best_info is None or best_info['params'] is None or np.isnan(best_info.get('avg_score', np.nan)):
              print(f"  No valid best parameters found for {clf_name} with {extractor_name} (or avg score was NaN). Skipping final test.")
              continue

         params = best_info['params']
         print(f"  Testing {clf_name} with Selected Best Params: {params}")

         try:
            clf = clf_class(**params)
            clf.fit(X_train_full, y_train_full)

            y_pred_test = clf.predict(X_test_full)

            # Pass class_names and num_classes for correct CM plotting and metric calculation
            test_metrics = evaluate_metrics(y_test_full, y_pred_test, class_names=class_names, num_classes=num_classes)

            final_test_results.append({
                'extractor': extractor_name,
                'classifier': clf_name,
                'params': params,
                'metrics': test_metrics,
                'y_true': y_test_full.tolist(), # Store for potential later use
                'y_pred': y_pred_test.tolist() # Store for potential later use
            })
         except Exception as e:
             print(f"\nError training/predicting selected {clf_name} with params {params} on test set: {e}")
             final_test_results.append({
                 'extractor': extractor_name,
                 'classifier': clf_name,
                 'params': params,
                 'error': str(e)
             })


print("\n--- Final Evaluation on Test Set Finished ---")
print(f"Total Final Test results stored (selected models): {len(final_test_results)}")


# --- 5. Display Final Test Results (with Plotting) ---
print("\n" + "="*60)
print("--- Summarizing Final Test Results (Selected Models) ---")
print("="*60)

if not final_test_results:
    print("No final test results to display.")
else:
    for result in final_test_results:
        print("\n" + "=" * 60)
        print(f"Extractor: {result.get('extractor', 'N/A')}")
        print(f"Classifier: {result.get('classifier', 'N/A')}")
        print(f"Parameters (Selected by K-Fold): {result.get('params', 'N/A')}")
        print("-" * 60)

        if 'error' in result:
             print(f"Error during final test: {result['error']}")
             continue

        metrics = result['metrics']

        # --- Print Scalar Metrics ---
        print(f"  Metrics on Test Set:")
        acc = metrics.get('accuracy')
        bal_acc = metrics.get('balanced_accuracy')
        prec_m = metrics.get('precision_macro')
        rec_m = metrics.get('recall_macro')
        f1_m = metrics.get('f1_macro')
        prec_w = metrics.get('precision_weighted') # Get weighted
        rec_w = metrics.get('recall_weighted')     # Get weighted
        f1_w = metrics.get('f1_weighted')         # Get weighted


        print(f"    Accuracy: {acc:.4f}" if acc is not None else "    Accuracy: N/A")
        print(f"    Balanced Accuracy: {bal_acc:.4f}" if bal_acc is not None else "    Balanced Accuracy: N/A")
        print(f"    Precision (macro): {prec_m:.4f}" if prec_m is not None else "    Precision (macro): N/A")
        print(f"    Recall (macro): {rec_m:.4f}" if rec_m is not None else "    Recall (macro): N/A")
        print(f"    F1-Score (macro): {f1_m:.4f}" if f1_m is not None else "    F1-Score (macro): N/A")
        print(f"    Precision (weighted): {prec_w:.4f}" if prec_w is not None else "    Precision (weighted): N/A") # Print weighted
        print(f"    Recall (weighted): {rec_w:.4f}" if rec_w is not None else "    Recall (weighted): N/A")       # Print weighted
        print(f"    F1-Score (weighted): {f1_w:.4f}" if f1_w is not None else "    F1-Score (weighted): N/A")     # Print weighted


        # --- Plot Confusion Matrix ---
        cm_list = metrics.get('confusion_matrix')
        if cm_list is not None and class_names is not None:
            cm_np = np.array(cm_list)

            # Dynamically determine figure size based on number of classes
            fig_size = max(6, num_classes * 0.7) # Scale with number of classes
            plt.figure(figsize=(fig_size, fig_size * 0.8))

            sns.heatmap(cm_np,
                        annot=True, fmt='d', cmap='Blues',
                        xticklabels=class_names, yticklabels=class_names)
            plt.xlabel('Predicted Label')
            plt.ylabel('True Label')

            params_dict_for_title = result.get('params', {})
            # Limit params in title for readability
            params_str_title = ", ".join([f"{k}={v}" for k, v in params_dict_for_title.items()])
            if len(params_str_title) > 50: # Truncate if too long
                params_str_title = params_str_title[:47] + "..."

            plt.title(f'Confusion Matrix: {result["classifier"]} ({result["extractor"]})\nParams: {params_str_title}')
            plt.tight_layout()
            plt.show()
        elif cm_list is not None:
             print("\n  Confusion Matrix (cannot plot without class names or CM data):")
             print(np.array(cm_list) if cm_list else "N/A")


        # --- Print Per-Class TP/TN/FP/FN ---
        cm_metrics_per_class = metrics.get('cm_metrics_per_class')
        if cm_metrics_per_class:
            print("\n  Per-Class TP/TN/FP/FN on Test Set:")
            # Sort keys alphabetically or by original class index if available
            sorted_class_labels = sorted(cm_metrics_per_class.keys(), key=lambda x: class_names.index(x) if class_names and x in class_names else x)

            for class_label in sorted_class_labels:
                cm_vals = cm_metrics_per_class.get(class_label, {}) # Use get in case a class key is missing (shouldn't happen with updated CM logic)
                tp = cm_vals.get('TP', 'N/A')
                tn = cm_vals.get('TN', 'N/A')
                fp = cm_vals.get('FP', 'N/A')
                fn = cm_vals.get('FN', 'N/A')
                print(f"    {class_label}: TP={tp}, TN={tn}, FP={fp}, FN={fn}")

        print("=" * 60)

print("\n--- All Final Test Results Displayed ---")

# --- 6. Identify and Display Overall Best Result ---
print("\n" + "="*60)
print("--- Overall Best Result on Test Set ---")
print("="*60)

best_result_entry = None
highest_balanced_accuracy = -1.0 # Using balanced accuracy as the primary selection metric

# Find the best result based on balanced accuracy on the test set
for result in final_test_results:

    if 'error' in result or result.get('metrics') is None:
        continue

    current_balanced_accuracy = result['metrics'].get('balanced_accuracy')

    if current_balanced_accuracy is not None: # Only consider results where balanced_accuracy was computed
        if best_result_entry is None or current_balanced_accuracy > highest_balanced_accuracy:
            highest_balanced_accuracy = current_balanced_accuracy
            best_result_entry = result

# Print the details of the best result found
if best_result_entry:
    print(f"\nOverall Best Model configuration based on Test Set Balanced Accuracy ({highest_balanced_accuracy:.4f}):")
    print("-" * 60)
    print(f"Extractor: {best_result_entry['extractor']}")
    print(f"Classifier: {best_result_entry['classifier']}")
    print(f"Parameters (Selected by K-Fold): {best_result_entry['params']}")
    print("-" * 60)
    print("Metrics on Test Set for the Best Model:")

    metrics = best_result_entry['metrics']
    acc = metrics.get('accuracy')
    bal_acc = metrics.get('balanced_accuracy')
    prec_m = metrics.get('precision_macro')
    rec_m = metrics.get('recall_macro')
    f1_m = metrics.get('f1_macro')
    prec_w = metrics.get('precision_weighted') # Get weighted
    rec_w = metrics.get('recall_weighted')     # Get weighted
    f1_w = metrics.get('f1_weighted')         # Get weighted

    print(f"  Accuracy: {acc:.4f}" if acc is not None else "  Accuracy: N/A")
    print(f"  Balanced Accuracy: {bal_acc:.4f}" if bal_acc is not None else "  Balanced Accuracy: N/A")
    print(f"  Precision (macro): {prec_m:.4f}" if prec_m is not None else "  Precision (macro): N/A")
    print(f"  Recall (macro): {rec_m:.4f}" if rec_m is not None else "  Recall (macro): N/A")
    print(f"  F1-Score (macro): {f1_m:.4f}" if f1_m is not None else "  F1-Score (macro): N/A")
    print(f"  Precision (weighted): {prec_w:.4f}" if prec_w is not None else "  Precision (weighted): N/A") # Print weighted
    print(f"  Recall (weighted): {rec_w:.4f}" if rec_w is not None else "  Recall (weighted): N/A")       # Print weighted
    print(f"  F1-Score (weighted): {f1_w:.4f}" if f1_w is not None else "  F1-Score (weighted): N/A")     # Print weighted


    # Optionally plot CM for the best model here as well
    cm_list = metrics.get('confusion_matrix')
    if cm_list is not None and class_names is not None:
        cm_np = np.array(cm_list)

        fig_size = max(6, num_classes * 0.7) # Scale with number of classes
        plt.figure(figsize=(fig_size, fig_size * 0.8))

        sns.heatmap(cm_np,
                    annot=True, fmt='d', cmap='Blues',
                    xticklabels=class_names, yticklabels=class_names)
        plt.xlabel('Predicted Label')
        plt.ylabel('True Label')

        params_dict_for_title = best_result_entry.get('params', {})
        params_str_title = ", ".join([f"{k}={v}" for k, v in params_dict_for_title.items()])
        if len(params_str_title) > 50:
            params_str_title = params_str_title[:47] + "..."

        plt.title(f'Confusion Matrix: {best_result_entry["classifier"]} ({best_result_entry["extractor"]})\nParams: {params_str_title}\nTest Set (Best Model)')
        plt.tight_layout()
        plt.show()

else:
    print("Could not determine the overall best result (perhaps all runs failed or had no valid balanced accuracy metric).")

print("="*60)
# Out:
# Usando o dispositivo: cuda
# Downloading dataset...
# Downloading from https://www.kaggle.com/api/v1/datasets/download/mudasirazhar/cyanotoxins-identification-dataset?dataset_version_number=1...
# 100%|██████████| 97.2M/97.2M [00:05<00:00, 18.6MB/s]
# Extracting files...
# Path to dataset files: /root/.cache/kagglehub/datasets/mudasirazhar/cyanotoxins-identification-dataset/versions/1
# Found Train and Test directories.
# Train dataset size: 2377
# Test dataset size: 595
# Classes: ['Anabaena', 'Aphanizomenon', 'Chroococcales', 'Cylindrospermopsis', 'Dolichospermum', 'Microcystis', 'Nostoc', 'Oscillatoria', 'Phormidium', 'Planktothrix', 'Raphidiopsis', 'Rivularia', 'Synechococcus']
# config.json:   0%|          | 0.00/453 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/343M [00:00<?, ?B/s]
# Some weights of ViTModel were not initialized from the model checkpoint at facebook/dino-vitb8 and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Loaded facebook/dino-vitb8 as AutoModel.
# Feature extractor model loaded and set to evaluation mode.
# config.json:   0%|          | 0.00/69.7k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/346M [00:00<?, ?B/s]
# Some weights of ViTModel were not initialized from the model checkpoint at google/vit-base-patch16-224 and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Loaded google/vit-base-patch16-224 as AutoModel.
# Feature extractor model loaded and set to evaluation mode.
# config.json:   0%|          | 0.00/69.7k [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/1.22G [00:00<?, ?B/s]
# Some weights of ViTModel were not initialized from the model checkpoint at google/vit-large-patch16-224 and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Loaded google/vit-large-patch16-224 as AutoModel.
# Feature extractor model loaded and set to evaluation mode.
#
# ============================================================
# --- Initial Feature Extraction (Full Train and Test) ---
# ============================================================
#
# Using extractor: DINO
# Extracting features for 2377 samples...
# Extracting Features:   0%|          | 0/38 [00:00<?, ?it/s]
# model.safetensors:   0%|          | 0.00/1.22G [00:00<?, ?B/s]
# Extracting Features: 100%|██████████| 38/38 [00:26<00:00,  1.41it/s]
# Extracting features for 595 samples...
# Extracting Features: 100%|██████████| 10/10 [00:06<00:00,  1.54it/s]
# Extracted features shape (Train): (2377, 768)
# Extracted features shape (Test): (595, 768)
#
# Using extractor: ViT-Base
# Extracting features for 2377 samples...
# Extracting Features: 100%|██████████| 38/38 [00:10<00:00,  3.69it/s]
# Extracting features for 595 samples...
# Extracting Features: 100%|██████████| 10/10 [00:02<00:00,  3.91it/s]
# Extracted features shape (Train): (2377, 768)
# Extracted features shape (Test): (595, 768)
#
# Using extractor: ViT-Large
# Extracting features for 2377 samples...
# Extracting Features: 100%|██████████| 38/38 [00:21<00:00,  1.73it/s]
# Extracting features for 595 samples...
# Extracting Features: 100%|██████████| 10/10 [00:05<00:00,  1.80it/s]
# Extracted features shape (Train): (2377, 1024)
# Extracted features shape (Test): (595, 1024)
#
# ============================================================
# --- Starting K-Fold Cross-Validation on Training Data ---
# ============================================================
#
# --- K-Fold for Extractor: DINO ---
#
# Processing Fold 1/5
#   Fold 1 SVM Params: 100%|██████████| 5/5 [00:05<00:00,  1.14s/it]
#   Fold 1 MLP Params: 100%|██████████| 5/5 [00:08<00:00,  1.75s/it]
#   Fold 1 RandomForest Params: 100%|██████████| 5/5 [00:39<00:00,  7.81s/it]
#   Fold 1 KNN Params: 100%|██████████| 5/5 [00:00<00:00, 28.56it/s]
# Processing Fold 2/5
#   Fold 2 SVM Params: 100%|██████████| 5/5 [00:05<00:00,  1.11s/it]
#   Fold 2 MLP Params: 100%|██████████| 5/5 [00:06<00:00,  1.28s/it]
#   Fold 2 RandomForest Params: 100%|██████████| 5/5 [00:39<00:00,  7.86s/it]
#   Fold 2 KNN Params: 100%|██████████| 5/5 [00:00<00:00, 29.05it/s]
# Processing Fold 3/5
#   Fold 3 SVM Params: 100%|██████████| 5/5 [00:05<00:00,  1.12s/it]
#   Fold 3 MLP Params: 100%|██████████| 5/5 [00:08<00:00,  1.74s/it]
#   Fold 3 RandomForest Params: 100%|██████████| 5/5 [00:39<00:00,  7.86s/it]
#   Fold 3 KNN Params: 100%|██████████| 5/5 [00:00<00:00, 35.66it/s]
# Processing Fold 4/5
#   Fold 4 SVM Params: 100%|██████████| 5/5 [00:05<00:00,  1.11s/it]
#   Fold 4 MLP Params: 100%|██████████| 5/5 [00:06<00:00,  1.36s/it]
#   Fold 4 RandomForest Params: 100%|██████████| 5/5 [00:38<00:00,  7.78s/it]
#   Fold 4 KNN Params: 100%|██████████| 5/5 [00:00<00:00, 35.13it/s]
# Processing Fold 5/5
#   Fold 5 SVM Params: 100%|██████████| 5/5 [00:05<00:00,  1.11s/it]
#   Fold 5 MLP Params: 100%|██████████| 5/5 [00:08<00:00,  1.72s/it]
#   Fold 5 RandomForest Params: 100%|██████████| 5/5 [00:39<00:00,  7.86s/it]
#   Fold 5 KNN Params: 100%|██████████| 5/5 [00:00<00:00, 35.26it/s]
# --- K-Fold for Extractor: ViT-Base ---
#
# Processing Fold 1/5
#   Fold 1 SVM Params: 100%|██████████| 5/5 [00:05<00:00,  1.09s/it]
#   Fold 1 MLP Params: 100%|██████████| 5/5 [00:11<00:00,  2.25s/it]
#   Fold 1 RandomForest Params: 100%|██████████| 5/5 [00:40<00:00,  8.12s/it]
#   Fold 1 KNN Params: 100%|██████████| 5/5 [00:00<00:00, 35.39it/s]
# Processing Fold 2/5
#   Fold 2 SVM Params: 100%|██████████| 5/5 [00:05<00:00,  1.10s/it]
#   Fold 2 MLP Params: 100%|██████████| 5/5 [00:11<00:00,  2.21s/it]
#   Fold 2 RandomForest Params: 100%|██████████| 5/5 [00:41<00:00,  8.22s/it]
#   Fold 2 KNN Params: 100%|██████████| 5/5 [00:00<00:00, 35.11it/s]
# Processing Fold 3/5
#   Fold 3 SVM Params: 100%|██████████| 5/5 [00:05<00:00,  1.11s/it]
#   Fold 3 MLP Params: 100%|██████████| 5/5 [00:09<00:00,  1.90s/it]
#   Fold 3 RandomForest Params: 100%|██████████| 5/5 [00:40<00:00,  8.16s/it]
#   Fold 3 KNN Params: 100%|██████████| 5/5 [00:00<00:00, 32.78it/s]
# Processing Fold 4/5
#   Fold 4 SVM Params: 100%|██████████| 5/5 [00:05<00:00,  1.12s/it]
#   Fold 4 MLP Params: 100%|██████████| 5/5 [00:09<00:00,  1.97s/it]
#   Fold 4 RandomForest Params: 100%|██████████| 5/5 [00:40<00:00,  8.15s/it]
#   Fold 4 KNN Params: 100%|██████████| 5/5 [00:00<00:00, 33.04it/s]
# Processing Fold 5/5
#   Fold 5 SVM Params: 100%|██████████| 5/5 [00:05<00:00,  1.12s/it]
#   Fold 5 MLP Params: 100%|██████████| 5/5 [00:11<00:00,  2.26s/it]
#   Fold 5 RandomForest Params: 100%|██████████| 5/5 [00:40<00:00,  8.07s/it]
#   Fold 5 KNN Params: 100%|██████████| 5/5 [00:00<00:00, 32.07it/s]
# --- K-Fold for Extractor: ViT-Large ---
#
# Processing Fold 1/5
#   Fold 1 SVM Params: 100%|██████████| 5/5 [00:07<00:00,  1.50s/it]
#   Fold 1 MLP Params: 100%|██████████| 5/5 [00:11<00:00,  2.36s/it]
#   Fold 1 RandomForest Params: 100%|██████████| 5/5 [00:47<00:00,  9.51s/it]
#   Fold 1 KNN Params: 100%|██████████| 5/5 [00:00<00:00, 30.30it/s]
# Processing Fold 2/5
#   Fold 2 SVM Params: 100%|██████████| 5/5 [00:07<00:00,  1.54s/it]
#   Fold 2 MLP Params: 100%|██████████| 5/5 [00:12<00:00,  2.45s/it]
#   Fold 2 RandomForest Params: 100%|██████████| 5/5 [00:48<00:00,  9.70s/it]
#   Fold 2 KNN Params: 100%|██████████| 5/5 [00:00<00:00, 30.55it/s]
# Processing Fold 3/5
#   Fold 3 SVM Params: 100%|██████████| 5/5 [00:07<00:00,  1.52s/it]
#   Fold 3 MLP Params: 100%|██████████| 5/5 [00:11<00:00,  2.40s/it]
#   Fold 3 RandomForest Params: 100%|██████████| 5/5 [00:47<00:00,  9.55s/it]
#   Fold 3 KNN Params: 100%|██████████| 5/5 [00:00<00:00, 30.75it/s]
# Processing Fold 4/5
#   Fold 4 SVM Params: 100%|██████████| 5/5 [00:07<00:00,  1.52s/it]
#   Fold 4 MLP Params: 100%|██████████| 5/5 [00:11<00:00,  2.36s/it]
#   Fold 4 RandomForest Params: 100%|██████████| 5/5 [00:47<00:00,  9.52s/it]
#   Fold 4 KNN Params: 100%|██████████| 5/5 [00:00<00:00, 27.30it/s]
# Processing Fold 5/5
#   Fold 5 SVM Params: 100%|██████████| 5/5 [00:07<00:00,  1.52s/it]
#   Fold 5 MLP Params: 100%|██████████| 5/5 [00:11<00:00,  2.35s/it]
#   Fold 5 RandomForest Params: 100%|██████████| 5/5 [00:47<00:00,  9.55s/it]
#   Fold 5 KNN Params: 100%|██████████| 5/5 [00:00<00:00, 30.59it/s]
# --- K-Fold Cross-Validation Finished ---
# Total K-Fold results stored (including errors): 300
#
# ============================================================
# --- Analyzing K-Fold Results and Selecting Best Models ---
# ============================================================
# Selecting best hyperparameters based on average 'balanced_accuracy' across folds.
#
# --- K-Fold Average Metrics Summary (Best per Classifier/Extractor Combo) ---
#
# Best K-Fold Result for Extractor: DINO, Classifier: SVM
#   Selected Params: {'C': 10}
#   Avg balanced_accuracy: 0.9363
#   Avg Metrics (Macro): Precision=0.9475, Recall=0.9363, F1=0.9370
#   Avg Metrics (Weighted): Precision=0.9615, Recall=0.9583, F1=0.9581
#   Avg Accuracy: 0.9583, Avg Balanced Accuracy: 0.9363
#
# Best K-Fold Result for Extractor: DINO, Classifier: MLP
#   Selected Params: {'hidden_layer_sizes': (50, 50), 'max_iter': 200, 'random_state': 42}
#   Avg balanced_accuracy: 0.9102
#   Avg Metrics (Macro): Precision=0.9023, Recall=0.9102, F1=0.9003
#   Avg Metrics (Weighted): Precision=0.9354, Recall=0.9323, F1=0.9322
#   Avg Accuracy: 0.9323, Avg Balanced Accuracy: 0.9102
#
# Best K-Fold Result for Extractor: DINO, Classifier: KNN
#   Selected Params: {'n_neighbors': 1}
#   Avg balanced_accuracy: 0.8969
#   Avg Metrics (Macro): Precision=0.8862, Recall=0.8969, F1=0.8859
#   Avg Metrics (Weighted): Precision=0.9442, Recall=0.9415, F1=0.9415
#   Avg Accuracy: 0.9415, Avg Balanced Accuracy: 0.8969
#
# Best K-Fold Result for Extractor: ViT-Large, Classifier: SVM
#   Selected Params: {'C': 10}
#   Avg balanced_accuracy: 0.8701
#   Avg Metrics (Macro): Precision=0.8928, Recall=0.8701, F1=0.8756
#   Avg Metrics (Weighted): Precision=0.9371, Recall=0.9348, F1=0.9341
#   Avg Accuracy: 0.9348, Avg Balanced Accuracy: 0.8701
#
# Best K-Fold Result for Extractor: ViT-Large, Classifier: MLP
#   Selected Params: {'hidden_layer_sizes': (100,), 'max_iter': 200, 'random_state': 42}
#   Avg balanced_accuracy: 0.8663
#   Avg Metrics (Macro): Precision=0.8770, Recall=0.8663, F1=0.8664
#   Avg Metrics (Weighted): Precision=0.9296, Recall=0.9272, F1=0.9269
#   Avg Accuracy: 0.9272, Avg Balanced Accuracy: 0.8663
#
# Best K-Fold Result for Extractor: ViT-Base, Classifier: SVM
#   Selected Params: {'C': 100}
#   Avg balanced_accuracy: 0.8584
#   Avg Metrics (Macro): Precision=0.8754, Recall=0.8584, F1=0.8626
#   Avg Metrics (Weighted): Precision=0.9334, Recall=0.9314, F1=0.9303
#   Avg Accuracy: 0.9314, Avg Balanced Accuracy: 0.8584
#
# Best K-Fold Result for Extractor: ViT-Large, Classifier: KNN
#   Selected Params: {'n_neighbors': 1}
#   Avg balanced_accuracy: 0.8535
#   Avg Metrics (Macro): Precision=0.8588, Recall=0.8535, F1=0.8458
#   Avg Metrics (Weighted): Precision=0.9155, Recall=0.9121, F1=0.9107
#   Avg Accuracy: 0.9121, Avg Balanced Accuracy: 0.8535
#
# Best K-Fold Result for Extractor: ViT-Base, Classifier: MLP
#   Selected Params: {'hidden_layer_sizes': (200, 200), 'max_iter': 200, 'random_state': 42}
#   Avg balanced_accuracy: 0.8487
#   Avg Metrics (Macro): Precision=0.8455, Recall=0.8487, F1=0.8422
#   Avg Metrics (Weighted): Precision=0.9151, Recall=0.9112, F1=0.9108
#   Avg Accuracy: 0.9112, Avg Balanced Accuracy: 0.8487
#
# Best K-Fold Result for Extractor: ViT-Base, Classifier: KNN
#   Selected Params: {'n_neighbors': 1}
#   Avg balanced_accuracy: 0.8067
#   Avg Metrics (Macro): Precision=0.8239, Recall=0.8067, F1=0.8072
#   Avg Metrics (Weighted): Precision=0.9008, Recall=0.8969, F1=0.8956
#   Avg Accuracy: 0.8969, Avg Balanced Accuracy: 0.8067
#
# Best K-Fold Result for Extractor: DINO, Classifier: RandomForest
#   Selected Params: {'n_estimators': 500, 'random_state': 42}
#   Avg balanced_accuracy: 0.6990
#   Avg Metrics (Macro): Precision=0.8847, Recall=0.6990, F1=0.7496
#   Avg Metrics (Weighted): Precision=0.8824, Recall=0.8650, F1=0.8574
#   Avg Accuracy: 0.8650, Avg Balanced Accuracy: 0.6990
#
# Best K-Fold Result for Extractor: ViT-Base, Classifier: RandomForest
#   Selected Params: {'n_estimators': 200, 'random_state': 42}
#   Avg balanced_accuracy: 0.5712
#   Avg Metrics (Macro): Precision=0.7576, Recall=0.5712, F1=0.6101
#   Avg Metrics (Weighted): Precision=0.8035, Recall=0.7972, F1=0.7765
#   Avg Accuracy: 0.7972, Avg Balanced Accuracy: 0.5712
#
# Best K-Fold Result for Extractor: ViT-Large, Classifier: RandomForest
#   Selected Params: {'n_estimators': 500, 'random_state': 42}
#   Avg balanced_accuracy: 0.5653
#   Avg Metrics (Macro): Precision=0.7443, Recall=0.5653, F1=0.5973
#   Avg Metrics (Weighted): Precision=0.8215, Recall=0.8040, F1=0.7832
#   Avg Accuracy: 0.8040, Avg Balanced Accuracy: 0.5653
#
# ============================================================
# --- Starting Final Evaluation on Test Set (Using Selected Best Models) ---
# ============================================================
#
# --- Testing with Extractor: DINO ---
#   Testing SVM with Selected Best Params: {'C': 10}
#   Testing MLP with Selected Best Params: {'hidden_layer_sizes': (50, 50), 'max_iter': 200, 'random_state': 42}
#   Testing RandomForest with Selected Best Params: {'n_estimators': 500, 'random_state': 42}
#   Testing KNN with Selected Best Params: {'n_neighbors': 1}
#
# --- Testing with Extractor: ViT-Base ---
#   Testing SVM with Selected Best Params: {'C': 100}
#   Testing MLP with Selected Best Params: {'hidden_layer_sizes': (200, 200), 'max_iter': 200, 'random_state': 42}
#   Testing RandomForest with Selected Best Params: {'n_estimators': 200, 'random_state': 42}
#   Testing KNN with Selected Best Params: {'n_neighbors': 1}
#
# --- Testing with Extractor: ViT-Large ---
#   Testing SVM with Selected Best Params: {'C': 10}
#   Testing MLP with Selected Best Params: {'hidden_layer_sizes': (100,), 'max_iter': 200, 'random_state': 42}
#   Testing RandomForest with Selected Best Params: {'n_estimators': 500, 'random_state': 42}
#   Testing KNN with Selected Best Params: {'n_neighbors': 1}
#
# --- Final Evaluation on Test Set Finished ---
# Total Final Test results stored (selected models): 12
#
# ============================================================
# --- Summarizing Final Test Results (Selected Models) ---
# ============================================================
#
# ============================================================
# Extractor: DINO
# Classifier: SVM
# Parameters (Selected by K-Fold): {'C': 10}
# ------------------------------------------------------------
#   Metrics on Test Set:
#     Accuracy: 0.9597
#     Balanced Accuracy: 0.9033
#     Precision (macro): 0.9089
#     Recall (macro): 0.9033
#     F1-Score (macro): 0.9038
#     Precision (weighted): 0.9602
#     Recall (weighted): 0.9597
#     F1-Score (weighted): 0.9597
#   Per-Class TP/TN/FP/FN on Test Set:
#     Anabaena: TP=54, TN=535, FP=4, FN=2
#     Aphanizomenon: TP=4, TN=590, FP=1, FN=0
#     Chroococcales: TP=31, TN=561, FP=1, FN=2
#     Cylindrospermopsis: TP=2, TN=591, FP=1, FN=1
#     Dolichospermum: TP=31, TN=559, FP=3, FN=2
#     Microcystis: TP=233, TN=359, FP=1, FN=2
#     Nostoc: TP=73, TN=522, FP=0, FN=0
#     Oscillatoria: TP=29, TN=561, FP=2, FN=3
#     Phormidium: TP=57, TN=529, FP=5, FN=4
#     Planktothrix: TP=18, TN=575, FP=1, FN=1
#     Raphidiopsis: TP=3, TN=591, FP=0, FN=1
#     Rivularia: TP=14, TN=575, FP=3, FN=3
#     Synechococcus: TP=22, TN=568, FP=2, FN=3
# ============================================================
#
# ============================================================
# Extractor: DINO
# Classifier: MLP
# Parameters (Selected by K-Fold): {'hidden_layer_sizes': (50, 50), 'max_iter': 200, 'random_state': 42}
# ------------------------------------------------------------
#   Metrics on Test Set:
#     Accuracy: 0.9395
#     Balanced Accuracy: 0.8705
#     Precision (macro): 0.8747
#     Recall (macro): 0.8705
#     F1-Score (macro): 0.8682
#     Precision (weighted): 0.9422
#     Recall (weighted): 0.9395
#     F1-Score (weighted): 0.9399
#   Per-Class TP/TN/FP/FN on Test Set:
#     Anabaena: TP=51, TN=536, FP=3, FN=5
#     Aphanizomenon: TP=3, TN=588, FP=3, FN=1
#     Chroococcales: TP=30, TN=557, FP=5, FN=3
#     Cylindrospermopsis: TP=2, TN=591, FP=1, FN=1
#     Dolichospermum: TP=31, TN=558, FP=4, FN=2
#     Microcystis: TP=231, TN=356, FP=4, FN=4
#     Nostoc: TP=72, TN=519, FP=3, FN=1
#     Oscillatoria: TP=29, TN=559, FP=4, FN=3
#     Phormidium: TP=54, TN=529, FP=5, FN=7
#     Planktothrix: TP=18, TN=575, FP=1, FN=1
#     Raphidiopsis: TP=3, TN=591, FP=0, FN=1
#     Rivularia: TP=15, TN=575, FP=3, FN=2
#     Synechococcus: TP=20, TN=570, FP=0, FN=5
# ============================================================
#
# ============================================================
# Extractor: DINO
# Classifier: RandomForest
# Parameters (Selected by K-Fold): {'n_estimators': 500, 'random_state': 42}
# ------------------------------------------------------------
#   Metrics on Test Set:
#     Accuracy: 0.8941
#     Balanced Accuracy: 0.7084
#     Precision (macro): 0.8318
#     Recall (macro): 0.7084
#     F1-Score (macro): 0.7431
#     Precision (weighted): 0.8934
#     Recall (weighted): 0.8941
#     F1-Score (weighted): 0.8875
#   Per-Class TP/TN/FP/FN on Test Set:
#     Anabaena: TP=48, TN=522, FP=17, FN=8
#     Aphanizomenon: TP=0, TN=591, FP=0, FN=4
#     Chroococcales: TP=31, TN=561, FP=1, FN=2
#     Cylindrospermopsis: TP=2, TN=592, FP=0, FN=1
#     Dolichospermum: TP=28, TN=560, FP=2, FN=5
#     Microcystis: TP=232, TN=350, FP=10, FN=3
#     Nostoc: TP=71, TN=516, FP=6, FN=2
#     Oscillatoria: TP=25, TN=558, FP=5, FN=7
#     Phormidium: TP=54, TN=516, FP=18, FN=7
#     Planktothrix: TP=17, TN=576, FP=0, FN=2
#     Raphidiopsis: TP=1, TN=591, FP=0, FN=3
#     Rivularia: TP=11, TN=575, FP=3, FN=6
#     Synechococcus: TP=12, TN=569, FP=1, FN=13
# ============================================================
#
# ============================================================
# Extractor: DINO
# Classifier: KNN
# Parameters (Selected by K-Fold): {'n_neighbors': 1}
# ------------------------------------------------------------
#   Metrics on Test Set:
#     Accuracy: 0.9681
#     Balanced Accuracy: 0.9155
#     Precision (macro): 0.9354
#     Recall (macro): 0.9155
#     F1-Score (macro): 0.9234
#     Precision (weighted): 0.9687
#     Recall (weighted): 0.9681
#     F1-Score (weighted): 0.9679
#   Per-Class TP/TN/FP/FN on Test Set:
#     Anabaena: TP=51, TN=536, FP=3, FN=5
#     Aphanizomenon: TP=4, TN=591, FP=0, FN=0
#     Chroococcales: TP=30, TN=562, FP=0, FN=3
#     Cylindrospermopsis: TP=2, TN=591, FP=1, FN=1
#     Dolichospermum: TP=32, TN=558, FP=4, FN=1
#     Microcystis: TP=235, TN=357, FP=3, FN=0
#     Nostoc: TP=73, TN=521, FP=1, FN=0
#     Oscillatoria: TP=32, TN=563, FP=0, FN=0
#     Phormidium: TP=59, TN=533, FP=1, FN=2
#     Planktothrix: TP=18, TN=575, FP=1, FN=1
#     Raphidiopsis: TP=3, TN=591, FP=0, FN=1
#     Rivularia: TP=16, TN=575, FP=3, FN=1
#     Synechococcus: TP=21, TN=568, FP=2, FN=4
# ============================================================
#
# ============================================================
# Extractor: ViT-Base
# Classifier: SVM
# Parameters (Selected by K-Fold): {'C': 100}
# ------------------------------------------------------------
#   Metrics on Test Set:
#     Accuracy: 0.9479
#     Balanced Accuracy: 0.8234
#     Precision (macro): 0.9034
#     Recall (macro): 0.8234
#     F1-Score (macro): 0.8503
#     Precision (weighted): 0.9476
#     Recall (weighted): 0.9479
#     F1-Score (weighted): 0.9462
#   Per-Class TP/TN/FP/FN on Test Set:
#     Anabaena: TP=53, TN=531, FP=8, FN=3
#     Aphanizomenon: TP=1, TN=590, FP=1, FN=3
#     Chroococcales: TP=31, TN=560, FP=2, FN=2
#     Cylindrospermopsis: TP=2, TN=592, FP=0, FN=1
#     Dolichospermum: TP=30, TN=558, FP=4, FN=3
#     Microcystis: TP=234, TN=357, FP=3, FN=1
#     Nostoc: TP=73, TN=521, FP=1, FN=0
#     Oscillatoria: TP=29, TN=560, FP=3, FN=3
#     Phormidium: TP=55, TN=530, FP=4, FN=6
#     Planktothrix: TP=18, TN=575, FP=1, FN=1
#     Raphidiopsis: TP=2, TN=591, FP=0, FN=2
#     Rivularia: TP=16, TN=575, FP=3, FN=1
#     Synechococcus: TP=20, TN=569, FP=1, FN=5
# ============================================================
#
# ============================================================
# Extractor: ViT-Base
# Classifier: MLP
# Parameters (Selected by K-Fold): {'hidden_layer_sizes': (200, 200), 'max_iter': 200, 'random_state': 42}
# ------------------------------------------------------------
#   Metrics on Test Set:
#     Accuracy: 0.9345
#     Balanced Accuracy: 0.8484
#     Precision (macro): 0.8764
#     Recall (macro): 0.8484
#     F1-Score (macro): 0.8571
#     Precision (weighted): 0.9360
#     Recall (weighted): 0.9345
#     F1-Score (weighted): 0.9343
#   Per-Class TP/TN/FP/FN on Test Set:
#     Anabaena: TP=53, TN=533, FP=6, FN=3
#     Aphanizomenon: TP=2, TN=588, FP=3, FN=2
#     Chroococcales: TP=29, TN=560, FP=2, FN=4
#     Cylindrospermopsis: TP=2, TN=592, FP=0, FN=1
#     Dolichospermum: TP=29, TN=559, FP=3, FN=4
#     Microcystis: TP=232, TN=357, FP=3, FN=3
#     Nostoc: TP=73, TN=520, FP=2, FN=0
#     Oscillatoria: TP=27, TN=558, FP=5, FN=5
#     Phormidium: TP=51, TN=529, FP=5, FN=10
#     Planktothrix: TP=19, TN=574, FP=2, FN=0
#     Raphidiopsis: TP=3, TN=591, FP=0, FN=1
#     Rivularia: TP=16, TN=574, FP=4, FN=1
#     Synechococcus: TP=20, TN=566, FP=4, FN=5
# ============================================================
#
# ============================================================
# Extractor: ViT-Base
# Classifier: RandomForest
# Parameters (Selected by K-Fold): {'n_estimators': 200, 'random_state': 42}
# ------------------------------------------------------------
#   Metrics on Test Set:
#     Accuracy: 0.8420
#     Balanced Accuracy: 0.6174
#     Precision (macro): 0.7456
#     Recall (macro): 0.6174
#     F1-Score (macro): 0.6493
#     Precision (weighted): 0.8332
#     Recall (weighted): 0.8420
#     F1-Score (weighted): 0.8286
#   Per-Class TP/TN/FP/FN on Test Set:
#     Anabaena: TP=48, TN=514, FP=25, FN=8
#     Aphanizomenon: TP=0, TN=591, FP=0, FN=4
#     Chroococcales: TP=23, TN=555, FP=7, FN=10
#     Cylindrospermopsis: TP=2, TN=592, FP=0, FN=1
#     Dolichospermum: TP=22, TN=558, FP=4, FN=11
#     Microcystis: TP=232, TN=346, FP=14, FN=3
#     Nostoc: TP=72, TN=514, FP=8, FN=1
#     Oscillatoria: TP=20, TN=556, FP=7, FN=12
#     Phormidium: TP=52, TN=515, FP=19, FN=9
#     Planktothrix: TP=16, TN=573, FP=3, FN=3
#     Raphidiopsis: TP=1, TN=591, FP=0, FN=3
#     Rivularia: TP=4, TN=575, FP=3, FN=13
#     Synechococcus: TP=9, TN=566, FP=4, FN=16
# ============================================================
#
# ============================================================
# Extractor: ViT-Base
# Classifier: KNN
# Parameters (Selected by K-Fold): {'n_neighbors': 1}
# ------------------------------------------------------------
#   Metrics on Test Set:
#     Accuracy: 0.9244
#     Balanced Accuracy: 0.8006
#     Precision (macro): 0.8255
#     Recall (macro): 0.8006
#     F1-Score (macro): 0.8005
#     Precision (weighted): 0.9287
#     Recall (weighted): 0.9244
#     F1-Score (weighted): 0.9241
#   Per-Class TP/TN/FP/FN on Test Set:
#     Anabaena: TP=46, TN=536, FP=3, FN=10
#     Aphanizomenon: TP=1, TN=588, FP=3, FN=3
#     Chroococcales: TP=25, TN=560, FP=2, FN=8
#     Cylindrospermopsis: TP=2, TN=588, FP=4, FN=1
#     Dolichospermum: TP=29, TN=555, FP=7, FN=4
#     Microcystis: TP=234, TN=353, FP=7, FN=1
#     Nostoc: TP=73, TN=515, FP=7, FN=0
#     Oscillatoria: TP=29, TN=563, FP=0, FN=3
#     Phormidium: TP=53, TN=529, FP=5, FN=8
#     Planktothrix: TP=19, TN=573, FP=3, FN=0
#     Raphidiopsis: TP=2, TN=591, FP=0, FN=2
#     Rivularia: TP=15, TN=577, FP=1, FN=2
#     Synechococcus: TP=22, TN=567, FP=3, FN=3
# ============================================================
#
# ============================================================
# Extractor: ViT-Large
# Classifier: SVM
# Parameters (Selected by K-Fold): {'C': 10}
# ------------------------------------------------------------
#   Metrics on Test Set:
#     Accuracy: 0.9597
#     Balanced Accuracy: 0.8744
#     Precision (macro): 0.9515
#     Recall (macro): 0.8744
#     F1-Score (macro): 0.9017
#     Precision (weighted): 0.9616
#     Recall (weighted): 0.9597
#     F1-Score (weighted): 0.9593
#   Per-Class TP/TN/FP/FN on Test Set:
#     Anabaena: TP=54, TN=536, FP=3, FN=2
#     Aphanizomenon: TP=2, TN=591, FP=0, FN=2
#     Chroococcales: TP=29, TN=558, FP=4, FN=4
#     Cylindrospermopsis: TP=2, TN=592, FP=0, FN=1
#     Dolichospermum: TP=31, TN=556, FP=6, FN=2
#     Microcystis: TP=234, TN=359, FP=1, FN=1
#     Nostoc: TP=71, TN=522, FP=0, FN=2
#     Oscillatoria: TP=29, TN=562, FP=1, FN=3
#     Phormidium: TP=58, TN=530, FP=4, FN=3
#     Planktothrix: TP=19, TN=575, FP=1, FN=0
#     Raphidiopsis: TP=3, TN=591, FP=0, FN=1
#     Rivularia: TP=15, TN=578, FP=0, FN=2
#     Synechococcus: TP=24, TN=566, FP=4, FN=1
# ============================================================
#
# ============================================================
# Extractor: ViT-Large
# Classifier: MLP
# Parameters (Selected by K-Fold): {'hidden_layer_sizes': (100,), 'max_iter': 200, 'random_state': 42}
# ------------------------------------------------------------
#   Metrics on Test Set:
#     Accuracy: 0.9378
#     Balanced Accuracy: 0.8149
#     Precision (macro): 0.8725
#     Recall (macro): 0.8149
#     F1-Score (macro): 0.8336
#     Precision (weighted): 0.9393
#     Recall (weighted): 0.9378
#     F1-Score (weighted): 0.9372
#   Per-Class TP/TN/FP/FN on Test Set:
#     Anabaena: TP=52, TN=536, FP=3, FN=4
#     Aphanizomenon: TP=1, TN=588, FP=3, FN=3
#     Chroococcales: TP=29, TN=557, FP=5, FN=4
#     Cylindrospermopsis: TP=2, TN=592, FP=0, FN=1
#     Dolichospermum: TP=29, TN=556, FP=6, FN=4
#     Microcystis: TP=232, TN=356, FP=4, FN=3
#     Nostoc: TP=71, TN=520, FP=2, FN=2
#     Oscillatoria: TP=26, TN=562, FP=1, FN=6
#     Phormidium: TP=57, TN=529, FP=5, FN=4
#     Planktothrix: TP=19, TN=573, FP=3, FN=0
#     Raphidiopsis: TP=2, TN=591, FP=0, FN=2
#     Rivularia: TP=14, TN=576, FP=2, FN=3
#     Synechococcus: TP=24, TN=567, FP=3, FN=1
# ============================================================
#
# ============================================================
# Extractor: ViT-Large
# Classifier: RandomForest
# Parameters (Selected by K-Fold): {'n_estimators': 500, 'random_state': 42}
# ------------------------------------------------------------
#   Metrics on Test Set:
#     Accuracy: 0.8588
#     Balanced Accuracy: 0.6028
#     Precision (macro): 0.7299
#     Recall (macro): 0.6028
#     F1-Score (macro): 0.6296
#     Precision (weighted): 0.8553
#     Recall (weighted): 0.8588
#     F1-Score (weighted): 0.8445
#   Per-Class TP/TN/FP/FN on Test Set:
#     Anabaena: TP=50, TN=520, FP=19, FN=6
#     Aphanizomenon: TP=0, TN=591, FP=0, FN=4
#     Chroococcales: TP=29, TN=558, FP=4, FN=4
#     Cylindrospermopsis: TP=1, TN=592, FP=0, FN=2
#     Dolichospermum: TP=20, TN=558, FP=4, FN=13
#     Microcystis: TP=231, TN=347, FP=13, FN=4
#     Nostoc: TP=72, TN=512, FP=10, FN=1
#     Oscillatoria: TP=19, TN=557, FP=6, FN=13
#     Phormidium: TP=54, TN=510, FP=24, FN=7
#     Planktothrix: TP=16, TN=575, FP=1, FN=3
#     Raphidiopsis: TP=0, TN=591, FP=0, FN=4
#     Rivularia: TP=4, TN=578, FP=0, FN=13
#     Synechococcus: TP=15, TN=567, FP=3, FN=10
# ============================================================
#
# ============================================================
# Extractor: ViT-Large
# Classifier: KNN
# Parameters (Selected by K-Fold): {'n_neighbors': 1}
# ------------------------------------------------------------
#   Metrics on Test Set:
#     Accuracy: 0.9496
#     Balanced Accuracy: 0.8565
#     Precision (macro): 0.9250
#     Recall (macro): 0.8565
#     F1-Score (macro): 0.8803
#     Precision (weighted): 0.9519
#     Recall (weighted): 0.9496
#     F1-Score (weighted): 0.9491
#   Per-Class TP/TN/FP/FN on Test Set:
#     Anabaena: TP=51, TN=537, FP=2, FN=5
#     Aphanizomenon: TP=2, TN=591, FP=0, FN=2
#     Chroococcales: TP=31, TN=561, FP=1, FN=2
#     Cylindrospermopsis: TP=2, TN=592, FP=0, FN=1
#     Dolichospermum: TP=30, TN=555, FP=7, FN=3
#     Microcystis: TP=235, TN=358, FP=2, FN=0
#     Nostoc: TP=72, TN=519, FP=3, FN=1
#     Oscillatoria: TP=28, TN=562, FP=1, FN=4
#     Phormidium: TP=57, TN=526, FP=8, FN=4
#     Planktothrix: TP=19, TN=573, FP=3, FN=0
#     Raphidiopsis: TP=3, TN=590, FP=1, FN=1
#     Rivularia: TP=14, TN=576, FP=2, FN=3
#     Synechococcus: TP=21, TN=570, FP=0, FN=4
# ============================================================
#
# --- All Final Test Results Displayed ---
#
# ============================================================
# --- Overall Best Result on Test Set ---
# ============================================================
#
# Overall Best Model configuration based on Test Set Balanced Accuracy (0.9155):
# ------------------------------------------------------------
# Extractor: DINO
# Classifier: KNN
# Parameters (Selected by K-Fold): {'n_neighbors': 1}
# ------------------------------------------------------------
# Metrics on Test Set for the Best Model:
#   Accuracy: 0.9681
#   Balanced Accuracy: 0.9155
#   Precision (macro): 0.9354
#   Recall (macro): 0.9155
#   F1-Score (macro): 0.9234
#   Precision (weighted): 0.9687
#   Recall (weighted): 0.9681
#   F1-Score (weighted): 0.9679
# ============================================================
